# %%
from math import *
import matplotlib.pyplot as plt
import numpy as np


def plot():
    x = np.arange(0, pi, 0.01)
    y = x*np.cos(x**2)+1
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('plot')
    plt.show()


def funcion(x):
    return x*cos(x**2)+1


def alg_biseccion(l_inferior, l_superior, tolerancia):
    x0 = l_inferior
    x1 = l_superior
    c_iteraciones = 0
    if(funcion(l_inferior)*funcion(l_superior) > 0):
        print('No podemos garantizar que exista una raiz porque evaluando ambos limites en la funcion tienen el mismo signo')

    while(abs(x1-x0) > tolerancia):
        x0 = x1
        x1 = (l_inferior+l_superior)/2
        # El cambio de signo se da en el intervalo [l_inferior,x1]
        if(funcion(l_inferior)*funcion(x1) < 0):
            l_superior = x1  # Ahora el nuevo limite superior es el punto medio
        # El cambio de signo se da en el intervalo [x1,l_superior]
        if (funcion(x1) * funcion(l_superior) < 0):
            l_inferior = x1  # Ahora el nuevo limite inferior es el punto medio
        print('Intervalo = [', l_inferior, ',', l_superior, ']')
        c_iteraciones += 1

    print('Despues de', c_iteraciones, 'iteraciones la raiz aproximada es',
          x1, 'con un error de', abs(funcion(x1)))


alg_biseccion(0, pi, 10**(-8))
# Out:
# Intervalo = [ 0 , 1.5707963267948966 ]
# Intervalo = [ 0.7853981633974483 , 1.5707963267948966 ]
# Intervalo = [ 1.1780972450961724 , 1.5707963267948966 ]
# Intervalo = [ 1.3744467859455345 , 1.5707963267948966 ]
# Intervalo = [ 1.4726215563702154 , 1.5707963267948966 ]
# Intervalo = [ 1.4726215563702154 , 1.521708941582556 ]
# Intervalo = [ 1.4971652489763856 , 1.521708941582556 ]
# Intervalo = [ 1.5094370952794707 , 1.521708941582556 ]
# Intervalo = [ 1.5094370952794707 , 1.5155730184310134 ]
# Intervalo = [ 1.512505056855242 , 1.5155730184310134 ]
# Intervalo = [ 1.512505056855242 , 1.5140390376431276 ]
# Intervalo = [ 1.5132720472491847 , 1.5140390376431276 ]
# Intervalo = [ 1.5136555424461562 , 1.5140390376431276 ]
# Intervalo = [ 1.5138472900446418 , 1.5140390376431276 ]
# Intervalo = [ 1.5139431638438847 , 1.5140390376431276 ]
# Intervalo = [ 1.5139911007435063 , 1.5140390376431276 ]
# Intervalo = [ 1.514015069193317 , 1.5140390376431276 ]
# Intervalo = [ 1.514015069193317 , 1.5140270534182223 ]
# Intervalo = [ 1.5140210613057696 , 1.5140270534182223 ]
# Intervalo = [ 1.514024057361996 , 1.5140270534182223 ]
# Intervalo = [ 1.514024057361996 , 1.5140255553901092 ]
# Intervalo = [ 1.514024057361996 , 1.5140248063760526 ]
# Intervalo = [ 1.514024057361996 , 1.5140244318690244 ]
# Intervalo = [ 1.514024057361996 , 1.51402424461551 ]
# Intervalo = [ 1.514024150988753 , 1.51402424461551 ]
# Intervalo = [ 1.5140241978021316 , 1.51402424461551 ]
# Intervalo = [ 1.5140242212088209 , 1.51402424461551 ]
# Intervalo = [ 1.5140242329121656 , 1.51402424461551 ]
# Intervalo = [ 1.5140242329121656 , 1.5140242387638378 ]
# Despues de 29 iteraciones la raiz aproximada es 1.5140242387638378 con un error de 1.589572873328393e-08

# %%
plot()
